# %%
# PIL - Python Imaging Library
# cv2 - Computer Vision

# %%
import cv2

# %%
img = cv2.imread('image.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1600, 2560, 3)

# %%
from google.colab.patches import cv2_imshow

# %%
img_2 = cv2.resize(img, (400,300))

# %%
cv2_imshow(img_2)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F3479342510>

# %%
sliced_img = img[300:600, 300:600, :]

# %%
cv2_imshow(sliced_img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F3470BF39D0>

# %%
img[0][0]
# Out:
# array([173, 176, 181], dtype=uint8)

# %%
# to convert image into grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=2560x1600 at 0x7F3470BF3AD0>
